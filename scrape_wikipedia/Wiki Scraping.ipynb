# %%
import time
import requests
from pathlib import Path
from typing import List, Tuple
import pycountry

API_URL_TMPL = "https://{lang}.wikipedia.org/w/api.php"
SLEEP        = 0.05   # small delay between requests
BASE_DIR     = Path.home() / "Desktop"
OUTPUT_ROOT  = BASE_DIR / "History_of_ideologies"
MAX_DEPTH    = 4

visited = set()

def sanitize(name: str) -> str:
    return "".join(c if c.isalnum() or c in " _-()" else "_" for c in name)

def get_english_name(lang_code: str) -> str:
    try:
        lang = pycountry.languages.get(alpha_2=lang_code) or pycountry.languages.get(alpha_3=lang_code)
        return lang.name if lang and hasattr(lang, 'name') else lang_code
    except:
        return lang_code

def query_api(lang: str, params: dict, retries: int = 3) -> dict:
    url = API_URL_TMPL.format(lang=lang)
    headers = {
        "User-Agent": "WikipediaScraper/1.0 (njian29@emory.edu)"
    }
    for attempt in range(retries):
        try:
            r = requests.get(url, params=params, headers=headers, timeout=30)
            r.raise_for_status()
            return r.json()
        except Exception as e:
            if attempt < retries - 1:
                time.sleep(2 ** attempt)  # exponential backoff
                continue
            raise

def get_category_members(lang: str, category: str, cmtype: str="page") -> List[str]:
    members, cont = [], None
    while True:
        params = {
            "action": "query", "format": "json", "list": "categorymembers",
            "cmtitle": f"Category:{category}", "cmtype": cmtype,
            "cmlimit": "500", "cmnamespace": "14" if cmtype=="subcat" else "0"
        }
        if cont:
            params["cmcontinue"] = cont
        data = query_api(lang, params)
        items = data["query"]["categorymembers"]
        if cmtype == "subcat":
            members += [it["title"].split("Category:",1)[-1] for it in items]
        else:
            members += [it["title"] for it in items]
        cont = data.get("continue", {}).get("cmcontinue")
        if not cont: break
    return members

def get_category_langlinks(lang: str, category: str) -> List[Tuple[str, str]]:
    params = {"action": "query", "format": "json", "prop": "langlinks",
              "titles": f"Category:{category}", "lllimit": "max"}
    data = query_api(lang, params)
    page = next(iter(data["query"]["pages"].values()))
    return [(ll["lang"], ll["*"]) for ll in page.get("langlinks", [])]

def get_langlinks(lang: str, title: str) -> List[Tuple[str, str]]:
    params = {"action": "query", "format": "json", "prop": "langlinks",
              "titles": title, "lllimit": "max"}
    data = query_api(lang, params)
    page = next(iter(data["query"]["pages"].values()))
    return [(ll["lang"], ll["*"]) for ll in page.get("langlinks", [])]

def fetch_extract(lang: str, title: str) -> str:
    params = {"action": "query", "format": "json", "prop": "extracts",
              "explaintext": True, "titles": title}
    data = query_api(lang, params)
    page = next(iter(data["query"]["pages"].values()))
    return page.get("extract", "")

def save_entry(title: str, lang: str, out_dir: Path):
    variants = [(lang, title)] + get_langlinks(lang, title)
    entry_dir = out_dir / sanitize(title)
    entry_dir.mkdir(parents=True, exist_ok=True)

    for lg2, loc_title in variants:
        key = (lg2, loc_title)
        if key in visited:
            continue
        visited.add(key)
        text = fetch_extract(lg2, loc_title)
        if not text.strip():
            continue
        fname = sanitize(get_english_name(lg2)) + ".txt"
        (entry_dir / fname).write_text(text, encoding="utf-8")
        print(f"✔ Saved: {loc_title} [{lg2}]")

def scrape_category(lang: str, category: str, out_dir: Path, depth: int=1):
    print(f"{'  '*(depth-1)}→ depth={depth}, scraping Category:{category} [{lang}]")

    for title in get_category_members(lang, category, cmtype="page"):
        save_entry(title, lang, out_dir)
        time.sleep(SLEEP)

    if depth < MAX_DEPTH:
        for subcat in get_category_members(lang, category, cmtype="subcat"):
            scrape_category(lang, subcat, out_dir / sanitize(subcat), depth+1)

def main():
    OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

    root_category = "History_of_ideologies"
    langlinks = get_category_langlinks("en", root_category)
    langs = [("en", root_category)] + langlinks

    print("Will scrape these category entries:")
    for lg, ttl in langs:
        print(f" - [{lg}] Category:{ttl}")

    for lg, ttl in langs:
        out_dir = OUTPUT_ROOT / lg / sanitize(ttl)
        scrape_category(lg, ttl, out_dir, depth=1)

    print(f"\n✅ All results saved to: {OUTPUT_ROOT}")

if __name__ == "__main__":
    main()
# Out:
# Will scrape these category entries:
#  - [en] Category:History_of_ideologies
#  - [ab] Category:Акатегориа:Аидеологиақәа рҭоурых
#  - [ar] Category:تصنيف:تاريخ العقائد
#  - [az] Category:Kateqoriya:İdeologiyalar tarixi
#  - [be-tarask] Category:Катэгорыя:Гісторыя ідэалёгіяў
#  - [bn] Category:বিষয়শ্রেণী:মতাদর্শের ইতিহাস
#  - [bs] Category:Kategorija:Historija ideologija
#  - [el] Category:Κατηγορία:Ιστορία των ιδεολογιών
#  - [eu] Category:Kategoria:Ideologien historia
#  - [fa] Category:رده:تاریخ ایدئولوژی
#  - [fi] Category:Luokka:Aatehistoria
#  - [gl] Category:Categoría:Historia das ideoloxías
#  - [hr] Category:Kategorija:Povijest ideologija
#  - [id] Category:Kategori:Sejarah ideologi
#  - [io] Category:Kategorio:Historio di ideologii
#  - [ka] Category:კატეგორია:იდეოლოგიების ისტორია
#  - [ru] Category:Категория:История идеологий
#  - [sr] Category:Категорија:Историја идеологија
#  - [vi] Category:Thể loại:Lịch sử ý thức hệ
#  - [zh] Category:Category:意识形态史
# → depth=1, scraping Category:History_of_ideologies [en]
# ✔ Saved: History of agrarianism [en]
# ✔ Saved: История аграризма [ru]
# ✔ Saved: History of capitalism [en]
# ✔ Saved: تاريخ الرأسمالية [ar]
# ✔ Saved: Kapitalizmin tarixi [az]
# ✔ Saved: Història del capitalisme [ca]
# ✔ Saved: مێژووی سەرمایەداری [ckb]
# ✔ Saved: Historia del capitalismo [es]
# ✔ Saved: Kapitalismoaren historia [eu]
# ✔ Saved: Histoire du capitalisme [fr]
# ✔ Saved: Historia do capitalismo [gl]
# ✔ Saved: Sejarah kapitalisme [id]
# ✔ Saved: 자본주의의 역사 [ko]
# ✔ Saved: د پانګوال نظام تاريخ [ps]
# ✔ Saved: Kapitalizmin tarihi [tr]
# ✔ Saved: Lịch sử chủ nghĩa tư bản [vi]
# ✔ Saved: 资本主义的历史 [zh]
# ✔ Saved: History of Islamism [en]
# ✔ Saved: History of liberalism [en]
# ✔ Saved: تاريخ الليبرالية [ar]
# ✔ Saved: উদারতাবাদের ইতিহাস [bn]
# ✔ Saved: Geschichte liberaler Parteien [de]
# ✔ Saved: Historia del liberalismo [es]
# ✔ Saved: تاریخ لیبرالیسم [fa]
# ✔ Saved: Historio di liberalismo [io]
# ✔ Saved: د ليبراليزم تاريخ (ليبراليزم د آزادي غوښتلو اند دی) [ps]
# ✔ Saved: História do liberalismo [pt]
# ✔ Saved: История либерализма [ru]
# ✔ Saved: Liberalismens historia [sv]
# ✔ Saved: Історія лібералізму [uk]
# ✔ Saved: Nationalism in antiquity [en]
# ✔ Saved: Nationalism in the Middle Ages [en]
# ✔ Saved: القومية في العصور الوسطى [ar]
# ✔ Saved: ناسیۆنالیزم لە سەدەکانی ناوەڕاستدا [ckb]
#   → depth=2, scraping Category:History of anarchism [en]
# ✔ Saved: History of anarchism [en]
# ✔ Saved: تاريخ اللاسلطوية [ar]
# ✔ Saved: Ιστορία του αναρχισμού [el]
# ✔ Saved: Historia del anarquismo [es]
# ✔ Saved: Histoire de l'anarchisme [fr]
# ✔ Saved: Անարխիզմի պատմություն [hy]
# ✔ Saved: Sejarah anarkisme [id]
# ✔ Saved: Saga stjórnleysisstefnu [is]
# ✔ Saved: Storia dell'anarchismo [it]
# ✔ Saved: Historia anarchismi [la]
# ✔ Saved: د انارشېزم تاریخ [ps]
# ✔ Saved: História do anarquismo [pt]
# ✔ Saved: История анархизма [ru]
# ✔ Saved: Anarkismens historia [sv]
# ✔ Saved: Історія анархізму [uk]
# ✔ Saved: 無政府主義歷史 [zh]
# ✔ Saved: 1881 Chicago Social Revolutionary Congress [en]
# ✔ Saved: 1881 London Social Revolutionary Congress [en]
# ✔ Saved: A las Barricadas [en]
# ✔ Saved: A las Barricadas [af]
# ✔ Saved: A les barricades [ca]
# ✔ Saved: A las barricadas [cs]
# ✔ Saved: A las barricadas [de]
# ✔ Saved: Στα οδοφράγματα [el]
# ✔ Saved: Al la barikadoj [eo]
# ✔ Saved: A las barricadas [es]
# ✔ Saved: A las barricadas [eu]
# ✔ Saved: A las barricadas [fr]
# ✔ Saved: A las barricadas [gl]
# ✔ Saved: A las Barricadas [id]
# ✔ Saved: A las barricadas [it]
# ✔ Saved: バリケードへ [ja]
# ✔ Saved: 바리케이드를 향해 [ko]
# ✔ Saved: A las Barricadas [lt]
# ✔ Saved: A las Barricadas [mk]
# ✔ Saved: A las barricadas [nn]
# ✔ Saved: A las barricadas [nb]
# ✔ Saved: A las barricadas [pl]
# ✔ Saved: ¡A Las Barricadas! [pt]
# ✔ Saved: A las barricadas [ru]
# ✔ Saved: A Las Barricadas [sk]
# ✔ Saved: На барикаде [sr]
# ✔ Saved: A las Barricadas [sv]
# ✔ Saved: A las barricadas [tr]
# ✔ Saved: A las Barricadas [uk]
# ✔ Saved: 到街壘去 [zh]
# ✔ Saved: Die Aktion [en]
# ✔ Saved: Die Aktion [de]
# ✔ Saved: Die Aktion [es]
# ✔ Saved: Die Aktion [fr]
# ✔ Saved: Die Aktion [hu]
# ✔ Saved: Die Aktion [it]
# ✔ Saved: ディー・アクティオーン [ja]
# ✔ Saved: Die Aktion [kk]
# ✔ Saved: Die Aktion [pt]
# ✔ Saved: Die Aktion [ro]
# ✔ Saved: Die Aktion [ru]
# ✔ Saved: Die Aktion [sv]
# ✔ Saved: Amakasu Incident [en]
# ✔ Saved: حادثة أماكاسو [ar]
# ✔ Saved: Amakasu-Zwischenfall [de]
# ✔ Saved: Incidente de Amakasu [es]
# ✔ Saved: Amakasuren gertakaria [eu]
# ✔ Saved: حادثه آماکاسو [fa]
# ✔ Saved: Incident d'Amakasu [fr]
# ✔ Saved: Insiden Amakasu [id]
# ✔ Saved: 甘粕事件 [ja]
# ✔ Saved: Инцидент Амакасу [mk]
# ✔ Saved: Incidente Amakasu [pt]
# ✔ Saved: Дело Амакасу [ru]
# ✔ Saved: Amakasuov incident [sh]
# ✔ Saved: 甘粕事件 [zh]
# ✔ Saved: American Letter Mail Company [en]
# ✔ Saved: American Letter Mail Company [es]
# ✔ Saved: Anarchism and violence [en]
# ✔ Saved: الأناركية والعنف [ar]
# ✔ Saved: Anarquismo y violencia [es]
# ✔ Saved: Anarquismo e violência [pt]
# ✔ Saved: Anarşizm ve şiddet [tr]
# ✔ Saved: Anarchist bombing campaign of 1888-1889 [en]
# ✔ Saved: Campagne d'attentats anarchistes de 1888-1889 [fr]
# ✔ Saved: Anarchist brigades in the Italian Resistance [en]
# ✔ Saved: تیپ‌های آنارشیست در مقاومت ایتالیا [fa]
# ✔ Saved: Brigate anarchiche operanti nella resistenza italiana [it]
# ✔ Saved: Anarchist Mountain [en]
# ✔ Saved: جبل اناركيست [arz]
# ✔ Saved: Anarchist Mountain [ceb]
# ✔ Saved: Anarchist Mountain [lld]
# ✔ Saved: Anarchist Mountain [sv]
# ✔ Saved: History of anarcho-syndicalism [en]
# ✔ Saved: Anarchist archives [en]
# ✔ Saved: Liste libertärer Bibliotheken und Archive [de]
# ✔ Saved: Archiwum anarchistyczne [pl]
# ✔ Saved: Arquivos anarquistas [pt]
# ✔ Saved: Battle of Ruovesi [en]
# ✔ Saved: Ruoveden taistelut [fi]
# ✔ Saved: Pertempuran Ruovesi [id]
# ✔ Saved: Café Terminus attack [en]
# ✔ Saved: Attentat du café Terminus [fr]
# ✔ Saved: Canut revolts [en]
# ✔ Saved: Revolta dels canuts [ca]
# ✔ Saved: Aufstand der Seidenweber in Lyon [de]
# ✔ Saved: Ribelo de la Kanusoj [eo]
# ✔ Saved: Révolte des canuts [fr]
# ✔ Saved: Լիոնի ապստամբություններ (1831, 1834) [hy]
# ✔ Saved: Rivolta dei Canut [it]
# ✔ Saved: ਲਿਓਨ ਦੇ ਵਿਦਰੋਹ [pa]
# ✔ Saved: Powstania tkaczy w Lyonie [pl]
# ✔ Saved: لیون دیاں بغاوتاں [pnb]
# ✔ Saved: Лионское восстание (1831) [ru]
# ✔ Saved: Повстання ткачів у Ліоні 1831 [uk]
# ✔ Saved: 里昂工人起义 [zh]
# ✔ Saved: Charter of Amiens [en]
# ✔ Saved: Carta d'Amiens [ca]
# ✔ Saved: Charta von Amiens [de]
# ✔ Saved: Amiena Ĉarto [eo]
# ✔ Saved: Carta de Amiens [es]
# ✔ Saved: Amienseko Gutuna [eu]
# ✔ Saved: Charte d'Amiens [fr]
# ✔ Saved: Carta d'Amiens [it]
# ✔ Saved: Амьен декларациясы [kk]
# ✔ Saved: Handvest van Amiens [nl]
# ✔ Saved: Carta de Amiens [pt]
# ✔ Saved: Амьенская хартия [ru]
# ✔ Saved: Amiensdeklarationen [sv]
# ✔ Saved: 亞眠憲章 [zh]
# ✔ Saved: Circle of Tchaikovsky [en]
# ✔ Saved: Círculo Chaikovski [es]
# ✔ Saved: Cercle Tchaïkovski [fr]
# ✔ Saved: Circolo Čajkovskij [it]
# ✔ Saved: チャイコフスキー団 [ja]
# ✔ Saved: ჩაიკოვსკელები [ka]
# ✔ Saved: Чайковцы [ru]
# ✔ Saved: Чайковці [uk]
# ✔ Saved: Clichy affair [en]
# ✔ Saved: Cas de Clichy [ca]
# ✔ Saved: Affaire de Clichy [fr]
# ✔ Saved: Contemporary anarchism [en]
# ✔ Saved: لاسلطوية معاصرة [ar]
# ✔ Saved: Nuntempa anarkiismo [eo]
# ✔ Saved: 現代無政府主義 [ja]
# ✔ Saved: Anarquismo contemporâneo [pt]
# ✔ Saved: Çağdaş anarşizm [tr]
# ✔ Saved: Сучасний анархізм [uk]
# ✔ Saved: Death in the Haymarket [en]
# ✔ Saved: Ère des attentats [en]
# ✔ Saved: Ère des attentats [fr]
# ✔ Saved: Don't mourn, organize! [en]
# ✔ Saved: Emma Goldman: The Anarchist Guest [en]
# ✔ Saved: Emma Goldman: The Anarchist Guest [cy]
# ✔ Saved: Explosion in Leontievsky Lane [en]
# ✔ Saved: Взрыв в Леонтьевском переулке [ru]
# ✔ Saved: Вибух у Леонтіївському провулку [uk]
# ✔ Saved: First of May Group [en]
# ✔ Saved: Grupo Primero de Mayo [ca]
# ✔ Saved: Grupo Primero de Mayo [es]
# ✔ Saved: Grupa Pierwszego Maja [pl]
# ✔ Saved: The Funeral of the Anarchist Galli [en]
# ✔ Saved: Les Funérailles de Galli l'anarchiste [fr]
# ✔ Saved: הלווייתו של האנרכיסט גאלי [he]
# ✔ Saved: I funerali dell'anarchico Galli [it]
# ✔ Saved: Galleanisti [en]
# ✔ Saved: Hague Congress (1872) [en]
# ✔ Saved: Congrés de la Haia de 1872 [ca]
# ✔ Saved: Κογκρέσο της Χάγης [el]
# ✔ Saved: Congreso de La Haya de 1872 [es]
# ✔ Saved: Haagin kongressi [fi]
# ✔ Saved: Congrès de La Haye (1872) [fr]
# ✔ Saved: קונגרס האג (1872) [he]
# ✔ Saved: Congresso dell'Aia (1872) [it]
# ✔ Saved: Haags congres van de Eerste Internationale [nl]
# ✔ Saved: Congresso de Haia [pt]
# ✔ Saved: Lahey Kongresi [tr]
# ✔ Saved: Haymarket affair [en]
# ✔ Saved: قضايا هايماركت [ar]
# ✔ Saved: Бунт на Хеймаркет [be]
# ✔ Saved: Бунт на Хеймаркет [bg]
# ✔ Saved: हेमार्केट घटना [bh]
# ✔ Saved: Nemiri na Haymarketu [bs]
# ✔ Saved: Revolta de Haymarket [ca]
# ✔ Saved: Haymarketský masakr [cs]
# ✔ Saved: Haymarketoptøjerne [da]
# ✔ Saved: Haymarket Riot [de]
# ✔ Saved: Εξέγερση του Χέιμαρκετ [el]
# ✔ Saved: Tumulto de Haymarket Square [eo]
# ✔ Saved: Revuelta de Haymarket [es]
# ✔ Saved: Haymarket afera [eu]
# ✔ Saved: ماجرای های‌مارکت [fa]
# ✔ Saved: Haymarketin tapaus [fi]
# ✔ Saved: Massacre de Haymarket Square [fr]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 148
#     145     print(f"\n✅ All results saved to: {OUTPUT_ROOT}")
#     147 if __name__ == "__main__":
# --> 148     main()
#
# Cell In[4], line 143, in main()
#     141 for lg, ttl in langs:
#     142     out_dir = OUTPUT_ROOT / lg / sanitize(ttl)
# --> 143     scrape_category(lg, ttl, out_dir, depth=1)
#     145 print(f"\n✅ All results saved to: {OUTPUT_ROOT}")
#
# Cell In[4], line 125, in scrape_category(lang, category, out_dir, depth)
#     123 if depth < MAX_DEPTH:
#     124     for subcat in get_category_members(lang, category, cmtype="subcat"):
# --> 125         scrape_category(lang, subcat, out_dir / sanitize(subcat), depth+1)
#
# Cell In[4], line 119, in scrape_category(lang, category, out_dir, depth)
#     117 # scrape pages in this category
#     118 for title in get_category_members(lang, category, cmtype="page"):
# --> 119     save_entry(title, lang, out_dir)
#     120     time.sleep(SLEEP)
#     122 # recurse into subcategories
#
# Cell In[4], line 106, in save_entry(title, lang, out_dir)
#     104     continue
#     105 visited.add(key)
# --> 106 text = fetch_extract(lg2, loc_title)
#     107 if not text.strip():
#     108     continue
#
# Cell In[4], line 90, in fetch_extract(lang, title)
#      87 """Download plain text extract of a page."""
#      88 params = {"action": "query", "format": "json", "prop": "extracts",
#      89           "explaintext": True, "titles": title}
# ---> 90 data = query_api(lang, params)
#      91 page = next(iter(data["query"]["pages"].values()))
#      92 return page.get("extract", "")
#
# Cell In[4], line 40, in query_api(lang, params, retries)
#      38 for attempt in range(retries):
#      39     try:
# ---> 40         r = requests.get(url, params=params, headers=headers, timeout=30)
#      41         r.raise_for_status()
#      42         return r.json()
#
# File /opt/anaconda3/lib/python3.13/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/anaconda3/lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/anaconda3/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/lib/python3.13/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /opt/anaconda3/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File /opt/anaconda3/lib/python3.13/site-packages/urllib3/connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     461 try:
#     462     # Trigger any extra validation we need to do.
#     463     try:
# --> 464         self._validate_conn(conn)
#     465     except (SocketTimeout, BaseSSLError) as e:
#     466         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File /opt/anaconda3/lib/python3.13/site-packages/urllib3/connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 # Force connect early to allow us to validate the connection.
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1096 if not conn.is_verified and not conn.proxy_is_verified:
#
# File /opt/anaconda3/lib/python3.13/site-packages/urllib3/connection.py:704, in HTTPSConnection.connect(self)
#     702 try:
#     703     sock: socket.socket | ssl.SSLSocket
# --> 704     self.sock = sock = self._new_conn()
#     705     server_hostname: str = self.host
#     706     tls_in_tls = False
#
# File /opt/anaconda3/lib/python3.13/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     193 """Establish a socket connection and set nodelay settings on it.
#     194
#     195 :return: New socket connection.
#     196 """
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#     205     raise NameResolutionError(self.host, self, e) from e
#
# File /opt/anaconda3/lib/python3.13/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:
